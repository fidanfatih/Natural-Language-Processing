# %%
# !pip install google-auth-oauthlib

# %%
# !pip install google-api-python-client

# %%
# !pip install google-api-python-client

# %%
# !pip install youtube-transcript-api

# %%
from youtube_transcript_api import YouTubeTranscriptApi

# %%
video_list = ["oQyaI7Bt1Ig","0W-EUVhqv98"]

# %%
video_sent = []
for i in video_list:
    var1 = YouTubeTranscriptApi.get_transcript(i)
    video_sent.append(var1)
video_sent
# Out:
# [[{'text': 'in the 19th century nikola tesla',
#    'start': 0.48,
#    'duration': 4.56},
#   {'text': 'demonstrated wireless control technology',
#    'start': 2.72,
#    'duration': 4.88},
#   {'text': 'for devices for the very first time he',
#    'start': 5.04,
#    'duration': 5.04},
#   {'text': 'controlled a toy boat using only radio',
#    'start': 7.6,
#    'duration': 4.88},
#   {'text': 'waves the crowd was witnessing something',
#    'start': 10.08,
#    'duration': 4.24},
#   {'text': 'like this for the first time they',
#    'start': 12.48,
#    'duration': 3.44},
#   {'text': 'thought tesla was controlling the boat',
#    'start': 14.32,
#    'duration': 4.24},
#   {'text': 'using magic or telepathy', 'start': 15.92, 'duration': 4.64},
#   {'text': 'an advanced version of this technology',
#    'start': 18.56,
#    'duration': 3.84},
#   {'text': 'is something we all use in our daily',
#    'start': 20.56,
#    'duration': 3.76},
# ...

# %%
len(video_sent[1])
# Out:
# 277

# %%
var2 = YouTubeTranscriptApi.get_transcript("0W-EUVhqv98")
var2
# Out:
# [{'text': "nikola tesla's mysterious invention the",
#   'start': 0.719,
#   'duration': 4.801},
#  {'text': 'earthquake machine was actually designed',
#   'start': 3.199,
#   'duration': 6.16},
#  {'text': 'to be an alternating current generator',
#   'start': 5.52,
#   'duration': 3.839},
#  {'text': 'this intriguing oscillating generator',
#   'start': 9.519,
#   'duration': 3.921},
#  {'text': 'was driven with a brilliantly designed',
#   'start': 11.44,
#   'duration': 4.0},
#  {'text': 'piston cylinder and an air spring',
#   'start': 13.44,
#   'duration': 3.04},
#  {'text': 'mechanism', 'start': 15.44, 'duration': 2.96},
#  {'text': "tesla's hope with this arrangement was",
#   'start': 16.48,
#   'duration': 4.48},
#  {'text': 'to get constant frequency current output',
#   'start': 18.4,
#   'duration': 4.48},
#  {'text': 'however this device did more than',
#   'start': 20.96,
#   'duration': 4.559},
#  {'text': 'expected tesla claimed the vibrations',
# ...

# %%
len(var2)
# Out:
# 277

# %%
var3 = YouTubeTranscriptApi.get_transcript("oQyaI7Bt1Ig")
var3
# Out:
# [{'text': 'in the 19th century nikola tesla', 'start': 0.48, 'duration': 4.56},
#  {'text': 'demonstrated wireless control technology',
#   'start': 2.72,
#   'duration': 4.88},
#  {'text': 'for devices for the very first time he',
#   'start': 5.04,
#   'duration': 5.04},
#  {'text': 'controlled a toy boat using only radio',
#   'start': 7.6,
#   'duration': 4.88},
#  {'text': 'waves the crowd was witnessing something',
#   'start': 10.08,
#   'duration': 4.24},
#  {'text': 'like this for the first time they',
#   'start': 12.48,
#   'duration': 3.44},
#  {'text': 'thought tesla was controlling the boat',
#   'start': 14.32,
#   'duration': 4.24},
#  {'text': 'using magic or telepathy', 'start': 15.92, 'duration': 4.64},
#  {'text': 'an advanced version of this technology',
#   'start': 18.56,
#   'duration': 3.84},
#  {'text': 'is something we all use in our daily',
#   'start': 20.56,
#   'duration': 3.76},
#  {'text': 'lives', 'start': 22.4, 'duration': 4.0},
# ...

# %%
len(var3)
# Out:
# 208

# %%
srt = YouTubeTranscriptApi.get_transcript("oQyaI7Bt1Ig")

# %%
for i in srt:
    print(i["text"])
# Out:
# in the 19th century nikola tesla
# demonstrated wireless control technology
# for devices for the very first time he
# controlled a toy boat using only radio
# waves the crowd was witnessing something
# like this for the first time they
# thought tesla was controlling the boat
# using magic or telepathy
# an advanced version of this technology
# is something we all use in our daily
# lives
# welcome to a design journey in which we
# will understand nikola tesla's cool and
# tricky inventions in a simple way
# this is the most important controlling
# part of nikola tesla's toy boat the
# rudder
# when the rudder is at an angle a lift
# force will be produced on it and the
# boat will turn due to the torque
# produced
# if the angle of the rudder changes the
# boat will be able to turn in different
# directions
# tesla was able to achieve three
# different angles for his boat's rudder
# zero degree
# plus 45 degrees
# and minus 45 degrees
# the rudder didn't have any other angles
# ...

# %%
print(srt)
# Out:
# [{'text': 'in the 19th century nikola tesla', 'start': 0.48, 'duration': 4.56}, {'text': 'demonstrated wireless control technology', 'start': 2.72, 'duration': 4.88}, {'text': 'for devices for the very first time he', 'start': 5.04, 'duration': 5.04}, {'text': 'controlled a toy boat using only radio', 'start': 7.6, 'duration': 4.88}, {'text': 'waves the crowd was witnessing something', 'start': 10.08, 'duration': 4.24}, {'text': 'like this for the first time they', 'start': 12.48, 'duration': 3.44}, {'text': 'thought tesla was controlling the boat', 'start': 14.32, 'duration': 4.24}, {'text': 'using magic or telepathy', 'start': 15.92, 'duration': 4.64}, {'text': 'an advanced version of this technology', 'start': 18.56, 'duration': 3.84}, {'text': 'is something we all use in our daily', 'start': 20.56, 'duration': 3.76}, {'text': 'lives', 'start': 22.4, 'duration': 4.0}, {'text': 'welcome to a design journey in which we', 'start': 24.32, 'duration': 4.56}, {'text': "will understand n
# ...

# %%
# pip install --upgrade google-api-python-client
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# pip install --upgrade google-auth-oauthlib google-auth-httplib2
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
